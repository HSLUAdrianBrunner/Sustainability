# %% [raw]
# from sklearn.preprocessing import StandardScaler
# import numpy as np
# import pandas as pd
# import import_ipynb
#
# path = "Data/"
# exog_features= pd.read_csv(path+ 'exog_features.csv')
# exog_features = exog_features.select_dtypes(include=['number'])
#
# scaler = StandardScaler()
# exog_scaled = pd.DataFrame(scaler.fit_transform(exog_features),
#                            columns=exog_features.columns,
#                            index=exog_features.index)
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.heatmap(exog_scaled.corr(), annot=True, fmt=".2f")
# plt.show()

# %%
import pandas as pd
fn02 = pd.read_csv("feature_importance_no2.csv", index_col=0)
fpm10 = pd.read_csv('feature_importance_pm10.csv',index_col=0)
fpm25 = pd.read_csv('feature_importance_pm25.csv',index_col=0)
fz.to_csv("feature_importance_merge.csv")
print(fn02.columns)
fz = pd.concat([fn02,fpm10,fpm25], axis=1)
fz
# Out:
# Index(['Importance_NO2'], dtype='object')
#                     Importance_NO2  Importance_PM10  Importance_PM25
# Feature
# Population_density      349.984741       241.530975       151.309586
# Population              217.160706       117.212196        64.525932
# Pop_age_0-14            170.617905       288.179657       158.135895
# Bus_motor_Total         160.018341       150.409698        94.460930
# GDP per capita          146.056519      1389.085571       501.360413
# Car_motor_Total         135.113449       202.801117       126.222404
# Pop_age_65-79           123.932411       359.523956       115.346786
# Modal_Share_Car         119.442642       148.931854       263.762543
# Bus_age_GT_20           112.401825        79.804802        77.088760
# Pop_age_GT_80           109.764412       402.938446       204.632126
# Pop_age_50-64           106.696075       124.699333       116.647614
# Car_age_GT_20            98.021683        83.235291       114.952400
# ...

# %%
##October##
##Dino | x#
##Nikos|  #
##Ilias|  #
##Alkis|  #
